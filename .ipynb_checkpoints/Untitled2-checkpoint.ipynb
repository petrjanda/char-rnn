-- %%
require 'nn'
-- Out:
-- {
--   Copy : table: 0x0b53dbc8
--   ConcatTable : table: 0x0b5843c8
--   L1HingeEmbeddingCriterion : table: 0x0b5528e0
--   test : function: 0x0b5cc748
--   tables :
--     {
--       full : function: 0x0b594e98
--       oneToOne : function: 0x0b597890
--       random : function: 0x0b597c98
--     }
--   SpatialAveragePooling : table: 0x0b4964b8
--   DistKLDivCriterion : table: 0x0b578898
--   MultiMarginCriterion : table: 0x0b56b068
--   StochasticGradient : table: 0x0b5643c0
--   SpatialConvolutionMM : table: 0x0b5921a0
--   MM : table: 0x0b557868
--   ParallelCriterion : table: 0x0b54af70
--   Reshape : table: 0x0b52c650
--   SpatialContrastiveNormalization : table: 0x0b1df320
--   Jacobian :
--     {
--       forward : function: 0x0b569f20
--       testAllUpdate : function: 0x0ae2b3b8
--       testDiagHessianInput : function: 0x0b492ff8
--       testDiagHessianWeight : function: 0x0b493018
--       testDiagHessianBias : function: 0x0ae2b378
-- ...

-- %%
table = nn.LookupTable(5,5)
